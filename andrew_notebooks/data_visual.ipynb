# %%
import scipy.io 
import pandas as pd 

data_path = "/users/azhan378/data/azhang/efficient-fpt/data/GLAMdata_monkey.csv"
pandas_data_df = pd.read_csv(data_path)

# %%
pandas_data_df
# Out:
#        subject  trial        rt  choice  item_value_0  item_value_1    gaze_0  \
# 0            0      0  0.427829       1             2             5  0.000000
# 1            0      1  0.548053       0             3             2  0.354538
# 2            0      2  0.480907       1             5             3  0.215705
# 3            0      3  0.598620       0             2             2  0.598138
# 4            0      4  0.527576       0             4             2  0.523217
# ...        ...    ...       ...     ...           ...           ...       ...
# 30041        1  14428  0.713350       0             3             3  0.562300
# 30042        1  14429  0.548896       0             5             3  0.647059
# 30043        1  14430  0.707233       0             5             3  0.639933
# 30044        1  14431  0.647123       0             3             3  0.512358
# 30045        1  14432  0.827002       1             1             2  0.363635
#
# ...

# %%
# data given by Vincent 

monkey_data_1 = pd.read_csv("/users/azhan378/data/azhang/efficient-fpt/data/behav_subj1.csv")
monkey_data_2 = pd.read_csv("/users/azhan378/data/azhang/efficient-fpt/data/behav_subj2.csv")
monkey_data_3 = pd.read_csv("/users/azhan378/data/azhang/efficient-fpt/data/behav_subj3.csv")
monkey_data_1
# Out:
#      trialNum  firstVal  secondVal  firstIsChosen  decisionRT  firstFixLat  \
# 0           6         1          3              0    0.827066        0.162
# 1          11         1          2              1    0.847049        0.164
# 2          18         1          5              0    0.897351        0.166
# 3          61         1          1              0    0.877376        0.163
# 4          62         1          5              0    0.937264        0.178
# ..        ...       ...        ...            ...         ...          ...
# 582       481         5          5              1    0.739332        0.213
# 583       494         5          2              1    0.807278        0.222
# 584       503         5          5              1    0.757297        0.184
# 585       518         5          3              1    0.687202        0.160
# 586       528         5          4              1    0.787275        0.195
#
#      secondFixLat  thirdFixLat
# 0           0.510          NaN
# ...

# %%
monkey_data_2
# Out:
#      trialNum  firstVal  secondVal  firstIsChosen  decisionRT  firstFixLat  \
# 0          10         1          5              0    0.727110        0.154
# 1          16         1          3              0    0.827561        0.259
# 2          33         1          3              0    0.796906        0.147
# 3          50         1          3              0    0.817211        0.147
# 4          57         1          4              0    0.787259        0.178
# ..        ...       ...        ...            ...         ...          ...
# 602       536         5          4              1    0.687310        0.159
# 603       542         5          3              1    0.727077        0.207
# 604       549         5          3              1    0.718524        0.189
# 605       596         5          2              1    0.697137        0.163
# 606       602         5          4              1    0.737211        0.151
#
#      secondFixLat  thirdFixLat
# 0           0.374          NaN
# ...
